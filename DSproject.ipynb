# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanabandi18/project/blob/main/DSproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTS
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
#DATA HANDLING
import pandas as pd
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
data = pd.read_csv('/content/Nutrition_Value_Dataset.csv')
print(data.head())
print(data.describe())
# Out:
#      Company  Energy (kCal)  Carbohydrates (g)  Protein (g)  Fiber (g)  \
# 0  Pizza Hut         432.60              65.64        17.91       3.85
# 1  Pizza Hut         407.60              67.11        16.73       7.19
# 2  Pizza Hut         423.33              59.97        18.26       3.49
# 3  Pizza Hut         474.03              52.86        20.07       3.79
# 4  Pizza Hut         408.16              53.93        19.91       2.46
#
#    Sugar (g)  Total Fat (g)  Saturated Fat   Trans Fat   Cholesterol   \
# 0        0.0          10.93            5.14        0.16         16.19
# 1        0.0           8.03            3.24        0.11         66.80
# 2        0.0          12.27            5.23        0.18         19.75
# 3        0.0          20.26            9.25        0.33         71.72
# 4        0.0          12.53            4.90        0.14         48.09
#
#     Sodium (g)
# 0       499.72
# 1       818.00
# 2       638.22
# 3      1128.11
# 4       942.67
# ...

# %%
X = data[["Energy (kCal)"]]
Y = data["Total Fat (g)"]
Y_ = data["Company"]

# %%
#DATA ANALYSIS
plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()

# %%
#LINEAR REGRESSION
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (LR): ",pred[0])
print("Accuracy (LR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# Predicted value (LR):  3.8430805804429293
# Accuracy (LR):  22.81578785963142
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
mdl = LogisticRegression()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (LGR): ",pred[0])
print("Accuracy (LGR): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['Energy (kCal)'], Y_, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Predicted value (LGR):  McDonalds
# Accuracy (LGR):  99.0

# %%
#SVR
from sklearn.svm import SVR
mdl = SVR(kernel = 'rbf')
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (SVR): ",pred[0])
print("Accuracy (SVR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# Predicted value (SVR):  0.43825784325184003
# Accuracy (SVR):  33.18486454119832

# %%
#NB
from sklearn.naive_bayes import GaussianNB
mdl = GaussianNB()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (NB): ",pred[0])
print("Accuracy (NB): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['Energy (kCal)'], Y_, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# Predicted value (NB):  McDonalds
# Accuracy (NB):  99.0
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
mdl = KNeighborsClassifier()
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (KNN): ",pred[0])
print("Accuracy (KNN): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['Energy (kCal)'], Y_, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (KNN):  McDonalds
# Accuracy (KNN):  79.0

# %%
#RANDOM FOREST CLASSIFICATION
from sklearn.ensemble import RandomForestClassifier
mdl = RandomForestClassifier(criterion='entropy')
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (RFC): ",pred[0])
print("Accuracy (RFC): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['Energy (kCal)'], Y_, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (RFC):  McDonalds
# Accuracy (RFC):  100.0

# %%
#RANDOM FOREST REGRESSION
from sklearn.ensemble import RandomForestRegressor
mdl = RandomForestRegressor(n_estimators=100,max_depth=6)
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (RFR): ",pred[0])
print("Accuracy (RFR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predicted value (RFR):  0.165124151360937
# Accuracy (RFR):  41.23605906709326

# %%
#DECISION TREE CLASSIFICATION
from sklearn.tree import DecisionTreeClassifier
mdl = DecisionTreeClassifier(max_leaf_nodes=3, random_state=1)
mdl.fit(X, Y_)
pred = mdl.predict([[6.575]])
print("Predicted value (DTC): ",pred[0])
print("Accuracy (DTC): ",mdl.score(X[:100], Y_[:100])*100)

plt.scatter(X['Energy (kCal)'], Y_, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Predicted value (DTC):  McDonalds
# Accuracy (DTC):  94.0

# %%
#DECISION TREE REGRESSION
from sklearn.tree import DecisionTreeRegressor
mdl =  DecisionTreeRegressor(max_depth=3)
mdl.fit(X, Y)
pred = mdl.predict([[6.575]])
print("Predicted value (DTR): ",pred[0])
print("Accuracy (DTR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Predicted value (DTR):  1.808082191780822
# Accuracy (DTR):  5.390103078311903

# %%
#MULTIPLE LINEAR REGRESSION
X = data[["Energy (kCal)","Total Fat (g)"]]
mdl = LinearRegression()
mdl.fit(X, Y)
pred = mdl.predict([[6.575, 4.09]])
print("Predicted value (MLR): ",pred[0])
print("Accuracy (MLR): ",mdl.score(X[:100], Y[:100])*100)

plt.scatter(X['Energy (kCal)'], Y, color='b')
plt.plot(X['Energy (kCal)'], mdl.predict(X),color='black',linewidth=3)
plt.xlabel('Energy (kCal)')
plt.ylabel('Total Fat (g)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted value (MLR):  4.089999999999999
# Accuracy (MLR):  100.0

# %%
score=91.24
MAE=1.678976757
print("Accuracy of Linear Regression",score)
print("MAE",MAE)
# Out:
# Accuracy of Linear Regression 91.24
# MAE 1.678976757

# %%
#TESTING
#RandomForestRegressor
x=data[['Energy (kCal)','Sugar (g)']]
y=data[['Total Fat (g)','Protein (g)']]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)



from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.metrics import r2_score
rf_model=RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(x_train, y_train)
y_pred=rf_model.predict(x_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
acc=mse
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

# Calculate the accuracy of the model
acc = mse# Calculate the accuracy of the model
print("Mean Square Error of RandomForest Regression",mse)
print("R2 score of RandomForest Regression",r2)
print("Mean absolute Error of RandomForest Regression",mae)


# Calculate the accuracy of the model
# Calculate the accuracy of the model

# Print the accuracy
print(f"Accuracy: {acc:.2f}")
# Out:
# Mean Square Error of RandomForest Regression 93.10361793438267
# R2 score of RandomForest Regression 0.74974109623612
# Mean absolute Error of RandomForest Regression 4.718323742138365
# Accuracy: 93.10
